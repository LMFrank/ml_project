# %%
import pandas as pd #导入Pandas
import numpy as np #导入NumPy
import matplotlib.pyplot as plt #导入绘图工具

df = pd.read_csv('特征构建示意数据集.csv') #导入数据
df #显示数据
# Out:
#         X     Y
# 0    0.27 -0.16
# 1   -0.80  0.65
# 2   -0.46 -0.42
# 3   -0.69  0.34
# 4   -0.16 -0.12
# ..    ...   ...
# 195  0.78  0.85
# 196  0.19 -0.11
# 197 -0.34  0.31
# 198 -0.45  0.34
# 199 -0.22  0.21
#
# [200 rows x 2 columns]

# %%
plt.scatter(df.X, df.Y) #X，Y散点图
plt.xlabel('X值') #x轴
plt.ylabel('Y值') #y轴
# Out:
# Text(0, 0.5, 'Y值')
# C:\ProgramLanguage\Anaconda3\envs\ml-gpu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.model_selection import train_test_split #导入train_test_split

df_x = df['X'].to_frame() #特征集
df_y = df['Y'] #标签集
X_train, X_test, y_train, y_test = train_test_split(df_x,df_y,test_size=0.3, random_state = 0) #拆分数据集

# %%
from sklearn.linear_model import LinearRegression #导入LinearRegression

model = LinearRegression() #创建模型
model.fit(X_train, y_train) #拟合模型
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([0.36533006, 0.37412715, 0.35895976, 0.3598698 , 0.3528928 ,
#        0.36017315, 0.32619818, 0.36836354, 0.33256849, 0.32286135,
#        0.32255801, 0.3453091 , 0.34682584, 0.32771492, 0.35076936,
#        0.33590531, 0.36381332, 0.34379236, 0.35744302, 0.31527766,
#        0.35956645, 0.32680488, 0.32650153, 0.31588435, 0.36806019,
#        0.36108319, 0.34500575, 0.32862496, 0.35471289, 0.33893879,
#        0.32741157, 0.34015218, 0.31982787, 0.33711871, 0.32983836,
#        0.34621914, 0.36502671, 0.34045553, 0.33651201, 0.35562293,
#        0.34894927, 0.3738238 , 0.36077984, 0.34288232, 0.35713967,
#        0.37139702, 0.31497431, 0.32498479, 0.31770444, 0.36138654,
#        0.32589483, 0.37109367, 0.33347853, 0.35622962, 0.33226514,
#        0.34348901, 0.34864593, 0.33742205, 0.3377254 , 0.31709774])

# %%
X_test
# Out:
#         X
# 18   0.66
# 170  0.95
# 107  0.45
# 98   0.48
# 177  0.25
# 182  0.49
# 5   -0.63
# 146  0.76
# 12  -0.42
# 152 -0.74
# 61  -0.75
# 125  0.00
# 180  0.05
# 154 -0.58
# 80   0.18
# 7   -0.31
# 33   0.61
# 130 -0.05
# 37   0.40
# 74  -0.99
# 183  0.47
# 145 -0.61
# 45  -0.62
# 159 -0.97
# 60   0.75
# 123  0.52
# 179 -0.01
# 185 -0.55
# 122  0.31
# 44  -0.21
# 16  -0.59
# 55  -0.17
# 150 -0.84
# 111 -0.27
# 22  -0.51
# 189  0.03
# 129  0.65
# 4   -0.16
# 83  -0.29
# 106  0.34
# 134  0.12
# 66   0.94
# 26   0.51
# 113 -0.08
# 168  0.39
# 63   0.86
# 8   -1.00
# 75  -0.67
# 118 -0.91
# 143  0.53
# 71  -0.64
# 124  0.85
# 184 -0.39
# 97   0.36
# 149 -0.43
# 24  -0.06
# 30   0.11
# 160 -0.26
# 40  -0.25
# 56  -0.93

# %%
plt.scatter(df.X, df.Y) #散点图
plt.scatter(X_test.reindex, model.predict(X_test), linestyle='--', color='red') #显示拟合曲线
plt.xlabel('X值') #x轴
plt.ylabel('Y值') #y轴
# Out:
# Text(0, 0.5, 'Y值')
# C:\ProgramLanguage\Anaconda3\envs\ml-gpu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X2_train = X_train.copy() #新特征训练集
X2_test = X_test.copy() #新特征测试集

# %%
X2_train['X2'] = X2_train['X']**2 #构建新特征X2
X2_train.head() #显示新特征训练集
# Out:
#         X      X2
# 131  0.21  0.0441
# 96   0.33  0.1089
# 181 -0.47  0.2209
# 19   0.13  0.0169
# 153 -0.52  0.2704

# %%
X2_test['X2'] = X2_test['X']**2 #构建新特征X2
X2_test# X2_test #显示新特征测试集
# Out:
#         X      X2
# 18   0.66  0.4356
# 170  0.95  0.9025
# 107  0.45  0.2025
# 98   0.48  0.2304
# 177  0.25  0.0625
# 182  0.49  0.2401
# 5   -0.63  0.3969
# 146  0.76  0.5776
# 12  -0.42  0.1764
# 152 -0.74  0.5476
# 61  -0.75  0.5625
# 125  0.00  0.0000
# 180  0.05  0.0025
# 154 -0.58  0.3364
# 80   0.18  0.0324
# 7   -0.31  0.0961
# 33   0.61  0.3721
# 130 -0.05  0.0025
# 37   0.40  0.1600
# 74  -0.99  0.9801
# 183  0.47  0.2209
# 145 -0.61  0.3721
# 45  -0.62  0.3844
# 159 -0.97  0.9409
# 60   0.75  0.5625
# 123  0.52  0.2704
# 179 -0.01  0.0001
# 185 -0.55  0.3025
# 122  0.31  0.0961
# 44  -0.21  0.0441
# 16  -0.59  0.3481
# 55  -0.17  0.0289
# 150 -0.84  0.7056
# 111 -0.27  0.0729
# 22  -0.51  0.2601
# 189  0.03  0.0009
# 129  0.65  0.4225
# 4   -0.16  0.0256
# 83  -0.29  0.0841
# 106  0.34  0.1156
# 134  0.12  0.0144
# 66   0.94  0.8836
# 26   0.51  0.2601
# 113 -0.08  0.0064
# 168  0.39  0.1521
# 63   0.86  0.7396
# 8   -1.00  1.0000
# 75  -0.67  0.4489
# 118 -0.91  0.8281
# 143  0.53  0.2809
# 71  -0.64  0.4096
# 124  0.85  0.7225
# 184 -0.39  0.1521
# 97   0.36  0.1296
# 149 -0.43  0.1849
# 24  -0.06  0.0036
# 30   0.11  0.0121
# 160 -0.26  0.0676
# 40  -0.25  0.0625
# 56  -0.93  0.8649

# %%
model2 = LinearRegression() #创建新模型
model2.fit(X2_train, y_train) #拟合新模型
# Out:
# LinearRegression()

# %%
plt.scatter(df.X, df.Y) #散点图
plt.scatter(X_test, model2.predict(X2_test), linestyle='--', color = 'red') #新拟合函数曲线
plt.xlabel('X值') #x轴
plt.ylabel('Y值') #y轴
# Out:
# Text(0, 0.5, 'Y值')
# C:\ProgramLanguage\Anaconda3\envs\ml-gpu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
